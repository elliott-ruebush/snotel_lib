# %% [markdown]
# # SNOTEL Metadata Fun Facts
#
# Quick look at the range in location, elevation, and time of the stations

# %%
import logging

from snotel_lib import SnotelClient
from snotel_lib.utils import get_min_and_max_rows

logging.basicConfig(level=logging.DEBUG, force=True)


client = SnotelClient()
metadata = client.get_stations_metadata(force_update=True)
metadata.head()
# Out:
# INFO:snotel_lib.client:Fetching metadata from internet: https://raw.githubusercontent.com/egagli/snotel_ccss_stations/main/all_stations.geojson
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com:443
# DEBUG:urllib3.connectionpool:https://raw.githubusercontent.com:443 "GET /egagli/snotel_ccss_stations/main/all_stations.geojson HTTP/1.1" 200 68095
# INFO:snotel_lib.client:Metadata retrieval took 0.26s (cache miss, 1060 stations)
#                         name network  elevation_m   latitude   longitude  \
# code
# 301_CA_SNTL         Adin Mtn  SNOTEL  1886.712036  41.235828 -120.791924
# 907_UT_SNTL      Agua Canyon  SNOTEL  2712.719971  37.522171 -112.271179
# 916_MT_SNTL       Albro Lake  SNOTEL  2529.840088  45.597229 -111.959023
# 1267_AK_SNTL  Alexander Lake  SNOTEL    48.768002  61.749668 -150.889664
# 908_WA_SNTL   Alpine Meadows  SNOTEL  1066.800049  47.779572 -121.698471
#
#                    state           huc   mgrs  \
# code
# 301_CA_SNTL   California  180200021403  10TFL
# 907_UT_SNTL         Utah  160300020301  12SUG
# 916_MT_SNTL      Montana  100200050701  12TVR
# 1267_AK_SNTL      Alaska  190205051106  05VPJ
# 908_WA_SNTL   Washington  171100100501  10TET
#
#                                mountain_range  begin_date    end_date  \
# code
# 301_CA_SNTL                Great Basin Ranges  1983-10-01  2026-02-24
# 907_UT_SNTL                  Colorado Plateau  1994-10-01  2026-02-24
# 916_MT_SNTL   Central Montana Rocky Mountains  1996-09-01  2026-02-24
# 1267_AK_SNTL                              NaN  2014-08-28  2026-02-24
# 908_WA_SNTL                     Cascade Range  1994-09-01  2026-02-24
#
#               csv_data                     geometry
# code
# 301_CA_SNTL       True  POINT (-120.79192 41.23583)
# 907_UT_SNTL       True  POINT (-112.27118 37.52217)
# 916_MT_SNTL       True  POINT (-111.95902 45.59723)
# 1267_AK_SNTL      True  POINT (-150.88966 61.74967)
# 908_WA_SNTL       True  POINT (-121.69847 47.77957)

# %%
# Highest and lowest elevation
get_min_and_max_rows(metadata, "elevation_m")
# Out:
#                         name network  elevation_m   latitude   longitude  \
# code
# 1058_CO_SNTL        Grayback  SNOTEL  3541.775879  37.470329 -106.537827
# 1267_AK_SNTL  Alexander Lake  SNOTEL    48.768002  61.749668 -150.889664
#
#                  state           huc   mgrs            mountain_range  \
# code
# 1058_CO_SNTL  Colorado  130100020101  13SCB  Southern Rocky Mountains
# 1267_AK_SNTL    Alaska  190205051106  05VPJ                       NaN
#
#               begin_date    end_date  csv_data                     geometry
# code
# 1058_CO_SNTL  2004-09-01  2026-02-24      True  POINT (-106.53783 37.47033)
# 1267_AK_SNTL  2014-08-28  2026-02-24      True  POINT (-150.88966 61.74967)

# %%
# Furthest North and South SNOTELs
get_min_and_max_rows(metadata, "latitude")
# Out:
#                        name network  elevation_m   latitude   longitude  \
# code
# 1175_AK_SNTL  Kelly Station  SNOTEL    94.487999  67.933327 -162.283325
# 755_NM_SNTL     Signal Peak  SNOTEL  2548.127930  32.924011 -108.145378
#
#                    state           huc   mgrs               mountain_range  \
# code
# 1175_AK_SNTL      Alaska  190504030802  03WXR                          NaN
# 755_NM_SNTL   New Mexico  150400010803  12SYB  Southwest Basins and Ranges
#
#               begin_date    end_date  csv_data                     geometry
# code
# 1175_AK_SNTL  1991-10-01  2026-02-24      True  POINT (-162.28333 67.93333)
# 755_NM_SNTL   1978-10-01  2026-02-24      True  POINT (-108.14538 32.92401)

# %%
# Furthest West and East
get_min_and_max_rows(metadata, "longitude")
# Out:
#                            name network  elevation_m   latitude   longitude  \
# code
# 920_SD_SNTL   North Rapid Creek  SNOTEL  1868.423950  44.206169 -103.787582
# 1175_AK_SNTL      Kelly Station  SNOTEL    94.487999  67.933327 -162.283325
#
#                      state           huc   mgrs mountain_range  begin_date  \
# code
# 920_SD_SNTL   South Dakota  101201100101  13TEJ            NaN  1996-08-09
# 1175_AK_SNTL        Alaska  190504030802  03WXR            NaN  1991-10-01
#
#                 end_date  csv_data                     geometry
# code
# 920_SD_SNTL   2026-02-24      True  POINT (-103.78758 44.20617)
# 1175_AK_SNTL  2026-02-24      True  POINT (-162.28333 67.93333)

# %%
# Newest and oldest
get_min_and_max_rows(metadata, "begin_date")
# Out:
#                              name network  elevation_m   latitude   longitude  \
# code
# TUN          Tunnel Guard Station    CCSS  2712.720000  36.366349 -118.289116
# 670_MT_SNTL    Northeast Entrance  SNOTEL  2240.280029  45.005650 -110.014061
#
#                   state           huc   mgrs               mountain_range  \
# code
# TUN          California  180300020101  11SLA                Sierra Nevada
# 670_MT_SNTL     Montana  100700010602  12TWQ  Greater Yellowstone Rockies
#
#              begin_date    end_date  csv_data                     geometry
# code
# TUN          2022-12-01  2026-02-24      True  POINT (-118.28912 36.36635)
# 670_MT_SNTL  1937-10-01  2026-02-24      True  POINT (-110.01406 45.00565)
